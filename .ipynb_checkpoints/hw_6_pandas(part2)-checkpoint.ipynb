# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Модуль 1.1: Python для аналитиков
#
# ### Домашнее задание
#
# P.S первую часть домашнего задания вы можете найти в файле с занятия
#
# **Дедлайн**: 13 января 23:59

# %% [markdown]
# ### **Задание №2**
#
# - Загрузите [датасет](https://disk.yandex.ru/d/20P4PUpwkigr2g) transaction_data.csv. Проверьте размер таблицы, типы переменных, число пропущенных значений и описательную статистику.
# - Сколько в датасете пропущенных значений?
# - Какие значения находятся в колонке transaction? Сколько наблюдений относятся к тому или иному уровню? Визуализируйте результат с помощью барплота. Подумайте, как можно улучшить график.
# - Сколько транзакций завершились ошибкой?
# - Сколько успешных транзакций осуществил каждый из пользователей? Постройте гистограмму распределения числа успешных транзакций.
# - Коллега прислал Вам обновленные [данные](https://yadi.sk/d/NtNP5zY0qU4ZAw). Постройте сводную таблицу user_vs_minute_pivot, где в качестве столбцов будут использованы имена пользователей, строк – минуты, значений – число совершенных операций в указанную минуту. Пропущенные значения заполните нулями.
# - Изучите представленный график. Помогите коллеге разобраться,  есть ли в данных ошибка, или же всё хорошо.
# - Если в данные закралась ошибка, исправьте её и сохраните правильное число минут, прошедших с начала дня, в колонку true_minute.
#
#
# ### Описание данных
#
# Имеются следующие данные:
#
# date – дата (2020-03-02 00:00:00 – 2020-03-02 01:29:05)
#
# name – имя пользователя
#
# transaction – статус транзакции
#
# minute* – сколько минут прошло с начала дня

# %% [markdown]
# **Важно:** ответ на каждый из вопросов надо предоставить в виде кода и краткого комментария к ответу

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('transaction_data.csv') # Загрузка датасета transaction_data.csv в переменную df

# %%
df.shape # определение размера датафрейма
# Out:
# (5315, 3)

# %%
df.dtypes # узнаем типы значений в столбцах df
# Out:
# date           object
# name           object
# transaction    object
# dtype: object

# %%
df.describe()
# Out:
#                        date           name  transaction
# count                  5315           5315         5315
# unique                 3373             56            3
# top     2020-03-02 00:33:10  Masha_Ozerova  successfull
# freq                      6            112         3692

# %%
df.isnull().sum() # находим число пропущенных значений в датафрейме
# Out:
# date           0
# name           0
# transaction    0
# dtype: int64

# %%
df['transaction'].unique() # узнаем, какие значения хранятся в столбце transaction в df
# Out:
# array(['cancelled', 'successfull', 'error'], dtype=object)

# %%
df \
    .groupby('transaction')\
    .agg({'transaction': 'count'})
    # находим кол-во транзакций по каждому из видов транзакций
# Out:
#              transaction
# transaction
# cancelled           1619
# error                  4
# successfull         3692

# %%
df \
    .groupby('transaction') \
    .agg({'transaction': 'count'}) \
    .plot \
    .bar() # рисуем столбчатые диаграммы для ранее найденных данных
# Out:
# <Axes: xlabel='transaction'>

# %%
len(df[df['transaction'] == 'error']) # находим число ошибочных транзакций
# Out:
# 4

# %%
df_tr = df[df['transaction'] == 'successfull'] # заводим новый ДФ для успешно завершённых транзакций

# %%
df_tr.shape # определение размера нового датафрейма
# Out:
# (3692, 3)

# %%
df_tr \
    .groupby('name') \
    .agg({'transaction': 'count'}) \
    .reset_index() 
    # поиск числа успешно завершённых транзакций для каждого имени
# Out:
#                    name  transaction
# 0    Ekaterina_Fedorova           72
# 1     Ekaterina_Ivanova           59
# 2     Ekaterina_Lesnova           63
# 3     Ekaterina_Ozerova           72
# 4     Ekaterina_Petrova           68
# 5   Ekaterina_Polyanova           68
# 6    Ekaterina_Smirnova           77
# 7        Irina_Fedorova           62
# 8         Irina_Ivanova           60
# 9         Irina_Lesnova           76
# 10        Irina_Ozerova           76
# 11        Irina_Petrova           66
# 12      Irina_Polyanova           59
# 13       Irina_Smirnova           63
# 14       Julia_Fedorova           67
# 15        Julia_Ivanova           63
# 16        Julia_Lesnova           55
# 17        Julia_Ozerova           60
# 18        Julia_Petrova           74
# 19      Julia_Polyanova           61
# 20       Julia_Smirnova           67
# 21      Lolita_Fedorova           70
# 22       Lolita_Ivanova           76
# 23       Lolita_Lesnova           52
# 24       Lolita_Ozerova           63
# 25       Lolita_Petrova           64
# 26     Lolita_Polyanova           59
# 27      Lolita_Smirnova           65
# 28       Masha_Fedorova           69
# 29        Masha_Ivanova           73
# 30        Masha_Lesnova           63
# 31        Masha_Ozerova           80
# 32        Masha_Petrova           62
# 33      Masha_Polyanova           78
# 34       Masha_Smirnova           57
# 35        Olga_Fedorova           72
# 36         Olga_Ivanova           64
# 37         Olga_Lesnova           56
# 38         Olga_Ozerova           65
# 39         Olga_Petrova           67
# 40       Olga_Polyanova           70
# 41        Olga_Smirnova           80
# 42    Svetlana_Fedorova           67
# 43     Svetlana_Ivanova           79
# 44     Svetlana_Lesnova           60
# 45     Svetlana_Ozerova           62
# 46     Svetlana_Petrova           58
# 47   Svetlana_Polyanova           78
# 48    Svetlana_Smirnova           82
# 49    Vasilisa_Fedorova           61
# 50     Vasilisa_Ivanova           62
# 51     Vasilisa_Lesnova           55
# 52     Vasilisa_Ozerova           62
# 53     Vasilisa_Petrova           63
# 54   Vasilisa_Polyanova           46
# 55    Vasilisa_Smirnova           64

# %%
df_tr \
    .groupby('name') \
    .agg({'transaction': 'count'}) \
    .reset_index() \
    .plot \
    .hist() 
    # строим гистограмму
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_updated = pd.read_csv("transaction_data_updated.csv") # считывание обновлённых данных в датафрейм df_updated

# %%
df_updated.shape
# Out:
# (5315, 4)

# %%
df_updated.head()
# Out:
#                   date                name  transaction  minute
# 0  2020-03-02 00:37:20   Ekaterina_Petrova    cancelled      37
# 1  2020-03-02 00:59:09      Irina_Fedorova  successfull      59
# 2  2020-03-02 01:06:14  Ekaterina_Smirnova  successfull       6
# 3  2020-03-02 00:02:58    Lolita_Polyanova    cancelled       2
# 4  2020-03-02 00:17:52      Julia_Smirnova    cancelled      17

# %%
df_updated.describe()
# Out:
#             minute
# count  5315.000000
# mean     24.622389
# std      16.649462
# min       0.000000
# 25%      11.000000
# 50%      22.000000
# 75%      37.000000
# max      59.000000

# %%
df_updated.isnull().sum() # ищем число пропусков в новом датафрейме
# Out:
# date           0
# name           0
# transaction    0
# minute         0
# dtype: int64

# %%
user_vs_minute_pivot = df_updated.pivot_table(values='transaction',  
                                              index='date', 
                                              columns='name', 
                                              aggfunc='count', 
                                              fill_value=0 
                                             )
# строим сводную таблицу, указанную в задании

# %%
user_vs_minute_pivot # смотрим на построенную нами таблицу
# Out:
# name                 Ekaterina_Fedorova  Ekaterina_Ivanova  Ekaterina_Lesnova  \
# date
# 2020-03-02 00:00:00                   0                  0                  0
# 2020-03-02 00:00:01                   0                  0                  0
# 2020-03-02 00:00:02                   0                  0                  0
# 2020-03-02 00:00:03                   0                  0                  0
# 2020-03-02 00:00:04                   0                  0                  0
# ...                                 ...                ...                ...
# 2020-03-02 01:28:58                   0                  0                  0
# 2020-03-02 01:29:00                   0                  0                  0
# 2020-03-02 01:29:01                   0                  0                  0
# 2020-03-02 01:29:02                   0                  0                  0
# 2020-03-02 01:29:05                   0                  0                  0
#
# name                 Ekaterina_Ozerova  Ekaterina_Petrova  \
# date
# 2020-03-02 00:00:00                  0                  0
# 2020-03-02 00:00:01                  0                  0
# 2020-03-02 00:00:02                  0                  0
# 2020-03-02 00:00:03                  0                  0
# 2020-03-02 00:00:04                  0                  0
# ...                                ...                ...
# 2020-03-02 01:28:58                  0                  0
# 2020-03-02 01:29:00                  0                  0
# 2020-03-02 01:29:01                  0                  0
# 2020-03-02 01:29:02                  0                  0
# 2020-03-02 01:29:05                  0                  0
#
# name                 Ekaterina_Polyanova  Ekaterina_Smirnova  Irina_Fedorova  \
# date
# 2020-03-02 00:00:00                    0                   0               0
# 2020-03-02 00:00:01                    1                   0               0
# 2020-03-02 00:00:02                    0                   0               0
# 2020-03-02 00:00:03                    0                   0               0
# 2020-03-02 00:00:04                    0                   0               0
# ...                                  ...                 ...             ...
# 2020-03-02 01:28:58                    0                   0               0
# 2020-03-02 01:29:00                    0                   0               0
# 2020-03-02 01:29:01                    0                   0               0
# 2020-03-02 01:29:02                    0                   0               0
# 2020-03-02 01:29:05                    0                   0               0
#
# name                 Irina_Ivanova  Irina_Lesnova  ...  Svetlana_Petrova  \
# date                                               ...
# 2020-03-02 00:00:00              0              0  ...                 0
# 2020-03-02 00:00:01              0              0  ...                 0
# 2020-03-02 00:00:02              0              0  ...                 0
# 2020-03-02 00:00:03              0              0  ...                 0
# 2020-03-02 00:00:04              0              0  ...                 0
# ...                            ...            ...  ...               ...
# 2020-03-02 01:28:58              0              0  ...                 0
# 2020-03-02 01:29:00              0              0  ...                 0
# 2020-03-02 01:29:01              0              0  ...                 0
# 2020-03-02 01:29:02              0              0  ...                 0
# 2020-03-02 01:29:05              0              0  ...                 0
#
# name                 Svetlana_Polyanova  Svetlana_Smirnova  Vasilisa_Fedorova  \
# date
# 2020-03-02 00:00:00                   0                  0                  0
# 2020-03-02 00:00:01                   0                  0                  0
# 2020-03-02 00:00:02                   0                  0                  0
# 2020-03-02 00:00:03                   0                  0                  0
# 2020-03-02 00:00:04                   0                  0                  0
# ...                                 ...                ...                ...
# 2020-03-02 01:28:58                   0                  0                  1
# 2020-03-02 01:29:00                   0                  0                  0
# 2020-03-02 01:29:01                   0                  0                  0
# 2020-03-02 01:29:02                   0                  0                  0
# 2020-03-02 01:29:05                   0                  0                  0
#
# name                 Vasilisa_Ivanova  Vasilisa_Lesnova  Vasilisa_Ozerova  \
# date
# 2020-03-02 00:00:00                 0                 0                 0
# 2020-03-02 00:00:01                 0                 0                 0
# 2020-03-02 00:00:02                 0                 0                 0
# 2020-03-02 00:00:03                 0                 0                 0
# 2020-03-02 00:00:04                 1                 0                 0
# ...                               ...               ...               ...
# 2020-03-02 01:28:58                 0                 0                 0
# 2020-03-02 01:29:00                 0                 0                 0
# 2020-03-02 01:29:01                 0                 0                 0
# 2020-03-02 01:29:02                 0                 0                 0
# 2020-03-02 01:29:05                 0                 0                 0
#
# name                 Vasilisa_Petrova  Vasilisa_Polyanova  Vasilisa_Smirnova
# date
# 2020-03-02 00:00:00                 0                   0                  0
# 2020-03-02 00:00:01                 0                   0                  0
# 2020-03-02 00:00:02                 0                   0                  0
# 2020-03-02 00:00:03                 0                   0                  0
# 2020-03-02 00:00:04                 0                   0                  0
# ...                               ...                 ...                ...
# 2020-03-02 01:28:58                 0                   0                  0
# 2020-03-02 01:29:00                 0                   1                  0
# 2020-03-02 01:29:01                 0                   0                  0
# 2020-03-02 01:29:02                 0                   0                  0
# 2020-03-02 01:29:05                 0                   0                  0
#
# [3373 rows x 56 columns]

# %% [markdown]
# ### **Задание №3**
#
# Имеются следующие данные о транзакциях в период с 01.12.2010 по 12.09.2011:
#
# InvoiceNo — номер транзакции
#
# StockCode — код товара
#
# Description — описание товара
#
# Quantity — количество единиц товара, добавленных в заказ
#
# InvoiceDate — дата транзакции
#
# UnitPrice — цена за единицу товара
#
# CustomerID — id клиента
#
# Country — страна, где проживает клиент
#
# Данные можно скачать [отсюда](https://yadi.sk/d/jjaJNk2w3C9AhA).
#
# В данной задаче ссылка для считывания данных лежит в переменной path_to_file.
#
# Импортируйте пандас и прочитайте данные с кодировкой ISO-8859-1. Запишите полученный датафрейм в retail, а названия колонок сохраните в переменную retail_columns.
#
#
# **Вопросы:**
# - Проверьте, встречаются ли в данных повторяющиеся наблюдения, и в качестве ответа укажите их количество. Если они есть, то удалите их из retail и скажите сколько дупликатов было в таблице?.
# - Данные содержат в себе записи как и об успешных транзакциях, так и об отмененных. Если пользователь отменил заказ, в начале номера транзакции (InvoiceNo) ставится C (canceled). Сколько всего заказов отменили пользователи?
# - Теперь отфильтруйте данные и оставьте в retail только те заказы, где Quantity > 0. В качестве ответа укажите число оставшихся строк.
# - Посчитайте число заказов для каждого пользователя (CustomerID) из Германии (Germany). Оставьте только тех, кто совершил более N транзакций (InvoiceNo), где N – 80% процентиль. Запишите полученные id пользователей в germany_top (не весь датафрейм, только id). (Отфильтрованные данные записаны в retail. Идентификатор заказа – InvoiceNo. Для каждого заказа в данных может встречаться более 1 строки.)
# - Используя объект с id пользователей (germany_top), полученный на предыдущем шаге, отфильтруйте наблюдения и оставьте в данных записи только по интересующим нас юзерам. Результирующий датафрейм запишите в top_retail_germany. (Датафрейм записан в retail, нужные id пользователей – в germany_top.)
# - Сгруппируйте top_retail_germany по коду товара (StockCode). Какой из продуктов добавляли в корзину чаще всего, кроме POST? Note: одним заказом считается единовременная покупка любого количества товара, т.е. без учета Quantity.
# - Вернемся к анализу полного датасета retail. Создайте колонку Revenue с суммой покупки, используя колонки Quantity и UnitPrice.(Отфильтрованные данные записаны в retail.)
# - Для каждой транзакции (InvoiceNo), посчитайте финальную сумму заказа. В качестве ответа укажите топ-5 (InvoiceNo) по сумме заказа (через запятую с пробелом и в порядке убывания TotalRevenue)

# %%
import zipfile

# %%
path_to_file = '5_data.csv.zip'
with zipfile.ZipFile(path_to_file, 'r') as zip_ref:
    file_inside_zip = zip_ref.namelist()[0]
    zip_ref.extractall()

# %%
retail = pd.read_csv(file_inside_zip, encoding='ISO-8859-1') # считываем данные в переменную retail, указанную в задании, используя предложенную кодировку

# %%
retail.shape
# Out:
# (541909, 8)

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
retail_columns = retail.columns

# %%
retail_columns = list(retail_columns) # в переменную retail_columns записываем список имен столбцов

# %%
retail_columns
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
retail.duplicated().astype(int).sum() # находим число строк-дупликатов (т.е. таких, которые уже содержатся в DF)
# Out:
# 5268

# %%
retail = retail.drop_duplicates() # удаляем те самые 5268 строк

# %%
retail.shape # результат на лицо!
# Out:
# (536641, 8)

# %%
retail[retail['InvoiceNo'].str[0] == 'C'].shape[0] # находим число отменённых заказов
# Out:
# 9251

# %%
retail = retail[retail['Quantity'] > 0] # оставляем только те строки, где значения в столбце Quantity > 0

# %%
retail.shape[0]
# Out:
# 526054

# %%
retail.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# Посчитайте число заказов для каждого пользователя (CustomerID) из Германии (Germany). Оставьте только тех, кто совершил более N транзакций (InvoiceNo), где N – 80% процентиль. Запишите полученные id пользователей в germany_top (не весь датафрейм, только id). (Отфильтрованные данные записаны в retail. Идентификатор заказа – InvoiceNo. Для каждого заказа в данных может встречаться более 1 строки.)

# %%
N = 80 # per cent

# %%
percentile_80 = retail \
    .query('Country=="Germany"') \
    .groupby('CustomerID')['InvoiceNo'] \
    .nunique() \
    .quantile(N/100) # Подсчёт (N/100)%

# %%
germany_top = retail \
    .query('Country=="Germany"') \
    .groupby('CustomerID')['InvoiceNo'] \
    .nunique() \
    .loc[lambda x: x > percentile_80] \
    .index \
    .tolist()

# %%
top_retail_germany = retail[retail['CustomerID'].isin(germany_top)]

# %%
top_retail_germany
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 1109      536527     22809              SET OF 6 T-LIGHTS SANTA         6
# 1110      536527     84347  ROTATING SILVER ANGELS T-LIGHT HLDR         6
# 1111      536527     84945   MULTI COLOUR SILVER T-LIGHT HOLDER        12
# 1112      536527     22242        5 HOOK HANGER MAGIC TOADSTOOL        12
# 1113      536527     22244           3 HOOK HANGER MAGIC GARDEN        12
# ...          ...       ...                                  ...       ...
# 541726    581570     22139     RETROSPOT TEA SET CERAMIC 11 PC          3
# 541727    581570     23077                  DOUGHNUT LIP GLOSS         20
# 541728    581570     20750             RED RETROSPOT MINI CASES         2
# 541729    581570     22505            MEMO BOARD COTTAGE DESIGN         4
# 541730    581570      POST                              POSTAGE         1
#
#             InvoiceDate  UnitPrice  CustomerID  Country
# 1109    12/1/2010 13:04       2.95     12662.0  Germany
# 1110    12/1/2010 13:04       2.55     12662.0  Germany
# 1111    12/1/2010 13:04       0.85     12662.0  Germany
# 1112    12/1/2010 13:04       1.65     12662.0  Germany
# 1113    12/1/2010 13:04       1.95     12662.0  Germany
# ...                 ...        ...         ...      ...
# 541726  12/9/2011 11:59       4.95     12662.0  Germany
# 541727  12/9/2011 11:59       1.25     12662.0  Germany
# 541728  12/9/2011 11:59       7.95     12662.0  Germany
# 541729  12/9/2011 11:59       4.95     12662.0  Germany
# 541730  12/9/2011 11:59      18.00     12662.0  Germany
#
# [4175 rows x 8 columns]

# %%
tmp = top_retail_germany.query('StockCode != "POST"').groupby('StockCode').agg({'Quantity':'count'})

# %%
tmp
# Out:
#            Quantity
# StockCode
# 10125             1
# 15036             8
# 15044A            2
# 15044B            2
# 15044D            2
# ...             ...
# 90170             1
# 90173             1
# 90202D            1
# 90204             1
# M                 2
#
# [1157 rows x 1 columns]

# %% [markdown]
# Вернемся к анализу полного датасета retail. Создайте колонку Revenue с суммой покупки, используя колонки Quantity и UnitPrice.(Отфильтрованные данные записаны в retail.)

# %%
retail['Revenue'] = retail['Quantity']*retail['UnitPrice']

# %%
retail
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country  Revenue
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom    15.30
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom    22.00
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom    20.34
# ...                 ...        ...         ...             ...      ...
# 541904  12/9/2011 12:50       0.85     12680.0          France    10.20
# 541905  12/9/2011 12:50       2.10     12680.0          France    12.60
# 541906  12/9/2011 12:50       4.15     12680.0          France    16.60
# 541907  12/9/2011 12:50       4.15     12680.0          France    16.60
# 541908  12/9/2011 12:50       4.95     12680.0          France    14.85
#
# [526054 rows x 9 columns]

# %% [markdown]
# Для каждой транзакции (InvoiceNo), посчитайте финальную сумму заказа. В качестве ответа укажите топ-5 (InvoiceNo) по сумме заказа (через запятую с пробелом и в порядке убывания TotalRevenue)

# %%
retail.groupby('InvoiceNo').agg({'Revenue':'sum'}).sort_values(by='Revenue', ascending=False).head()
# Out:
#              Revenue
# InvoiceNo
# 581483     168469.60
# 541431      77183.60
# 574941      52940.94
# 576365      50653.91
# 556444      38970.00
